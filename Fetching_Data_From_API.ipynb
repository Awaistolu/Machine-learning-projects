# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=2165a4b2bb67ea9bc2dc66c1ab553b51&language=en-US&page=1')

# %%
df_temp=pd.DataFrame(response.json()['results'])[['id','overview','popularity','title','release_date','vote_average','vote_count']]

# %%
df_temp
# Out:
#         id                                           overview  popularity  \
# 0    19404  Raj is a rich, carefree, happy-go-lucky second...      23.393
# 1   730154  A tragic accident lead to Kaori's blindness, b...      14.859
# 2      278  Framed in the 1940s for the double murder of h...      67.043
# 3      238  Spanning the years 1945 to 1955, a chronicle o...      73.762
# 4      424  The true story of how businessman Oskar Schind...      45.548
# 5   724089  Professor Gabriel Emerson finally learns the t...      11.192
# 6      240  In the continuing saga of the Corleone crime f...      45.411
# 7   696374  An intriguing and sinful exploration of seduct...      10.028
# 8   761053  The final part of the film adaption of the ero...      22.876
# 9   372058  High schoolers Mitsuha and Taki are complete s...     166.716
# 10  372754  Rihito Sajo, an honor student with a perfect s...      13.755
# 11     129  A young girl, Chihiro, becomes trapped in a st...      81.150
# 12  632632  The film centers on the love relationship amon...     131.301
# 13  496243  All unemployed, Ki-taek's family takes peculia...      98.491
# 14  255709  After 8-year-old So-won narrowly survives a br...      27.657
# 15  283566  In the aftermath of the Fourth Impact, strande...     168.257
# 16     389  The defense and the prosecution have rested an...      25.546
# 17     497  A supernatural tale set on death row in a Sout...      83.112
# 18     155  Batman raises the stakes in his war on crime. ...      82.194
# 19   40096  The lively Jack the Cricket and the sly Chicó ...       9.967
#
#                                      title release_date  vote_average  \
# 0              Dilwale Dulhania Le Jayenge   1995-10-20           8.7
# 1                           Your Eyes Tell   2020-10-23           8.7
# 2                 The Shawshank Redemption   1994-09-23           8.7
# 3                            The Godfather   1972-03-14           8.7
# 4                         Schindler's List   1993-11-30           8.6
# 5                Gabriel's Inferno Part II   2020-07-31           8.6
# 6                   The Godfather: Part II   1974-12-20           8.6
# 7                        Gabriel's Inferno   2020-05-29           8.6
# 8               Gabriel's Inferno Part III   2020-11-19           8.6
# 9                               Your Name.   2016-08-26           8.5
# 10                Dou kyu sei – Classmates   2016-02-20           8.5
# 11                           Spirited Away   2001-07-20           8.5
# 12                                   Given   2020-08-22           8.5
# 13                                Parasite   2019-05-30           8.5
# 14                                    Hope   2013-10-02           8.5
# 15  Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08           8.5
# 16                            12 Angry Men   1957-04-10           8.5
# 17                          The Green Mile   1999-12-10           8.5
# 18                         The Dark Knight   2008-07-14           8.5
# 19                            A Dog's Will   2000-09-15           8.5
#
#     vote_count
# 0         3418
# 1          241
# 2        20767
# 3        15491
# 4        12395
# 5         1383
# 6         9335
# 7         2203
# 8          944
# 9         8359
# 10         204
# 11       12448
# 12         293
# 13       13133
# 14         313
# 15         457
# 16        6178
# 17       13500
# 18       26846
# 19         857

# %%
df=pd.DataFrame()

# %%
# for i in range(1,485):
#     response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=2165a4b2bb67ea9bc2dc66c1ab553b51&language=en-US&page={}'.format(i))
#     df_temp=pd.DataFrame(response.json()['results'])[['id','overview','popularity','title','release_date','vote_average','vote_count']]
#     df=df.append(df_temp,ignore_index=True)
